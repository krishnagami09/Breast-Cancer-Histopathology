# %% [markdown]
# # Introduction

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
mkdir /content/dataset/

# %%
mkdir /content/dataset/initialPath

# %%
mkdir /content/dataset/finalPath

# %%
! unzip "gdrive/MyDrive/Colab Notebooks/Breast_Cancer_Classification/dataset/breast-histopathology-images" -d /content/dataset/initialPath
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y1951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y2001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y2251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y2301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y2351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2351_y2401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y1901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2401_y2301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2451_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2451_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2451_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2451_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2451_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2451_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2451_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2451_y1601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2451_y1701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2451_y1751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2501_y2001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2501_y2051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2501_y2101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2501_y2151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2501_y2201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2501_y2251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2501_y2301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2501_y2351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y1501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y1701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y1751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y1801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y1851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x251_y851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2551_y1701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2551_y1951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2551_y2001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2551_y2051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2601_y1801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2601_y1851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2601_y1901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2601_y1951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x2601_y2001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y1601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y1701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y1751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y1_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y51_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x301_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x351_y101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x351_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x351_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x351_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x351_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x351_y151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x351_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x351_y1701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x351_y1_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x351_y51_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y1601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y1_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y51_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x401_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y1051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y1601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y51_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x451_y851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y1051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y1501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x501_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x51_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x51_y1701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x51_y1751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y1501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x551_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y1001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y1051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x601_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y1051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x651_y801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x701_y851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y1001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x751_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y1001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y1051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x801_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y1001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y1051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y1501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x851_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y1001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y1051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x901_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y1001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y1051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y1551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/0/9346_idx5_x951_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1301_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1351_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1401_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1451_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1501_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1551_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1601_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y1951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y2001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y2051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y2101_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y2151_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1001_y2201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1301_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1351_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1401_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1451_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1501_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1551_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1601_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y1951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y2001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y2051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y2101_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y2151_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1051_y2201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1301_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1351_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1401_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1451_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1501_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1551_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1601_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y1951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y2001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y2051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y2101_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y2151_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y2201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1101_y2251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1301_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1351_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1401_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1451_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1501_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1551_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1601_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y1951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y2001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y2051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y2101_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y2151_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y2201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1151_y2251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1301_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1351_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1401_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1451_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1501_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1551_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1601_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y1951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y2001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y2051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y2101_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y2151_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y2201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1201_y2251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1301_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1351_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1401_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1451_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1501_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1551_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1601_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y1951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y2001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y2051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y2101_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y2151_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y2201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1251_y2251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1301_y1151_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1301_y1201_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1301_y1251_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1301_y1301_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1301_y1351_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1301_y1401_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9346/1/9346_idx5_x1301_y1451_class1.png
# ...
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x701_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x701_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1151_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1201_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1251_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y1951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y2001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x751_y701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1051_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1301_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1351_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y1901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x801_y751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y1001_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y1501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y1551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y1601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y1801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y1851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y1901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x851_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y101_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y1451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y1501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y1551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y1601_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y1701_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y1751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y1801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y1851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y1901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y451_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y51_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x901_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y1501_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y1551_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y1651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y1751_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y1801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y1851_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y1901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y1951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y401_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y651_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y801_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y901_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/0/9383_idx5_x951_y951_class0.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1701_y751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1701_y801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1701_y851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1701_y901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1701_y951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1751_y1001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1751_y651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1751_y701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1751_y751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1751_y801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1751_y851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1751_y901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1751_y951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1801_y1001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1801_y1051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1801_y601_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1801_y651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1801_y701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1801_y751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1801_y801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1801_y851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1801_y901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1801_y951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1851_y1001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1851_y1051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1851_y601_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1851_y651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1851_y701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1851_y751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1851_y801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1851_y851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1851_y901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1851_y951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1901_y1001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1901_y1051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1901_y601_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1901_y651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1901_y701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1901_y751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1901_y801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1901_y851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1901_y901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1901_y951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1951_y1001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1951_y1051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1951_y601_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1951_y651_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1951_y701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1951_y751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1951_y801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1951_y851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1951_y901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x1951_y951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2001_y1001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2001_y1051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2001_y701_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2001_y751_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2001_y801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2001_y851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2001_y901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2001_y951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2051_y1001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2051_y1051_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2051_y801_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2051_y851_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2051_y901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2051_y951_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2101_y1001_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2101_y901_class1.png
#   inflating: /content/dataset/initialPath/IDC_regular_ps50_idx5/9383/1/9383_idx5_x2101_y951_class1.png

# %%
mkdir /content/output

# %%
mkdir /content/utils

# %%
cp 'gdrive/MyDrive/Colab Notebooks/Breast_Cancer_Classification/utils/config.py' '/content/utils/config.py'

# %%
cp 'gdrive/MyDrive/Colab Notebooks/Breast_Cancer_Classification/utils/conv_bc_model.py' '/content/utils/conv_bc_model.py'

# %%
cp 'gdrive/MyDrive/Colab Notebooks/Breast_Cancer_Classification/utils/create_dataset.py' '/content/utils/create_dataset.py'

# %%
cp 'gdrive/MyDrive/Colab Notebooks/Breast_Cancer_Classification/utils/getPaths.py' '/content/utils/getPaths.py'

# %% [markdown]
# Running the Build Dataset file to shuffle and create the train test val folders and files

# %%
! python /content/utils/create_dataset.py
# Out:
# 555048
# 555048
# Making 'training' split
# 'Creating /content/dataset/finalPath/training' directory
# 'creating /content/dataset/finalPath/training/0' directory
# 'creating /content/dataset/finalPath/training/1' directory
# Making 'validation' split
# 'Creating /content/dataset/finalPath/validation' directory
# 'creating /content/dataset/finalPath/validation/0' directory
# 'creating /content/dataset/finalPath/validation/1' directory
# Making 'testing' split
# 'Creating /content/dataset/finalPath/testing' directory
# 'creating /content/dataset/finalPath/testing/1' directory
# 'creating /content/dataset/finalPath/testing/0' directory

# %% [markdown]
# -------------------------------------------------------------------------------

# %% [markdown]
# ## Model Building and Evaluation

# %%
# Mounting the google drive
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
# Google Drive Path
# gDrivePath = "gdrive/MyDrive/Colab Notebooks/Breast_Cancer_Classification/"

# %%
# import sys
# sys.path.append(gDrivePath)

# %%
# Setting the matplotlib backend so that if required then images can be saved in the background
import matplotlib
matplotlib.use("Agg")
# %matplotlib inline

# %%
# Importing the libraries
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc, roc_auc_score
from tensorflow.keras.optimizers import Adam
from utils import config
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
import pandas as pd
import seaborn as sns
import cv2

# %%
# pip install seaborn

# %%
# Defining a function for plotting the count of data against each class in each directory
def plotData(dirPath):
    # Get the path to the benign and malignant sub-directories
    benign_cases_dir = dirPath+ '/0/'
    malignant_cases_dir = dirPath + '/1/'

    # Get the list of all the images
    benign_cases = glob.glob(benign_cases_dir + '*.png')
    malignant_cases = glob.glob(malignant_cases_dir + '*.png')

    # An empty list. We will insert the data into this list in (img_path, label) format
    data1 = []

    # Go through all the benign cases. The label for these cases will be 0
    for img in benign_cases:
        data1.append((img,0))

    # Go through all the malignant cases. The label for these cases will be 1
    for img in malignant_cases:
        data1.append((img, 1))

    # Get a pandas dataframe from the data we have in our list 
    data1 = pd.DataFrame(data1, columns=['image', 'label'],index=None)

    # Shuffle the data 
    data1 = data1.sample(frac=1.).reset_index(drop=True)
    
    
    
    # Get the counts for each class
    cases_count = data1['label'].value_counts()
    print(cases_count)

    # Plot the results 
    plt.figure(figsize=(10,8))
    sns.barplot(x=cases_count.index, y= cases_count.values)
    plt.title('Number of cases', fontsize=14)
    plt.xlabel('Case type', fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.xticks(range(len(cases_count.index)), ['benign(0)', 'malignant(1)'])
    plt.show()

# %%
plotData(config.TRAIN_PATH)
# Out:
# 0    182977
# 1     72713
# Name: label, dtype: int64

# %%
plotData(config.TEST_PATH)
# Out:
# 0    71572
# 1    28213
# Name: label, dtype: int64

# %%
plotData(config.VAL_PATH)
# Out:
# 0    30640
# 1    11994
# Name: label, dtype: int64

# %%
# Get the path to the benign and malignant sub-directories
benign_cases_dir = config.TRAIN_PATH + '/0/'
malignant_cases_dir = config.TRAIN_PATH + '/1/'

# Get the list of all the images
benign_cases = glob.glob(benign_cases_dir + '*.png')
malignant_cases = glob.glob(malignant_cases_dir + '*.png')

# An empty list. We will insert the data into this list in (img_path, label) format
train_data1 = []

# Go through all the benign cases. The label for these cases will be 0
for img in benign_cases:
    train_data1.append((img,0))

# Go through all the malignant cases. The label for these cases will be 1
for img in malignant_cases:
    train_data1.append((img, 1))

# Get a pandas dataframe from the data we have in our list 
train_data1 = pd.DataFrame(train_data1, columns=['image', 'label'],index=None)

# %%
# Get few samples for both the classes
malignant_samples = (train_data1[train_data1['label']==1]['image'].iloc[:5]).tolist()
benign_samples = (train_data1[train_data1['label']==0]['image'].iloc[:5]).tolist()

# Concat the data in a single list and del the above two list
samples = malignant_samples + benign_samples
del malignant_samples, benign_samples

# Plot the data 
f, ax = plt.subplots(2,5, figsize=(30,10))
for i in range(10):
    img = cv2.imread(samples[i])
    ax[i//5, i%5].imshow(img, cmap='gray')
    if i<5:
        ax[i//5, i%5].set_title("malignant")
    else:
        ax[i//5, i%5].set_title("benign")
    ax[i//5, i%5].axis('off')
    ax[i//5, i%5].set_aspect('auto')
plt.show()

# %% [markdown]
# If we look carefully, then there are some cases where we won't be able to differentiate between a benign case and a malignant case with the naked eye. If we can build a robust classifier, it would be a great assist for the doctor too.

# %%
# Defining a method to get the number of files given a path
def retrieveNumberOfFiles(path):
    list1 = []
    for file_name in glob.iglob(path+'/**/*.png', recursive=True):
        list1.append(file_name)
    return len(list1)

# %%
# Defining a method to plot training and validation accuracy and loss
def training_plot(H, N, plotPath):
    plt.style.use("ggplot")
    plt.figure()
    plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
    plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
    plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
    plt.title("Training Loss and Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Loss/Accuracy")
    plt.legend(loc="lower left")
    plt.savefig(plotPath)

# %%
# Checking for the total number of image paths in training, validation and testing directories
totalTrain = retrieveNumberOfFiles(config.TRAIN_PATH)
totalVal = retrieveNumberOfFiles(config.VAL_PATH)
totalTest = retrieveNumberOfFiles(config.TEST_PATH)

# %%
# Defining a method to get the number of files given a path
def getAllFiles(path):
    list1 = []
    for file_name in glob.iglob(path+'/**/*.png', recursive=True):
        list1.append(file_name)
    return list1

# %%
# Retrieving all files from train directory
allTrainFiles = getAllFiles(config.TRAIN_PATH)

# %%
# Calculating the total number of training images against each class and then store the class weights in a dictionary
trainLabels = [int(p.split(os.path.sep)[-2]) for p in allTrainFiles]
trainLabels = to_categorical(trainLabels)
classSumTotals = trainLabels.sum(axis=0)
classWeight = dict()

# Looping over all classes and calculate the class weights
for i in range(0, len(classSumTotals)):
    classWeight[i] = classSumTotals.max() / classSumTotals[i]

# %%
# Initialize the training data augmentation object
## preprocess_input will scale input pixels between -1 and 1
## rotation_range is a value in degrees (0-180), a range within which to randomly rotate pictures
## zoom_range is for randomly zooming inside pictures
## width_shift and height_shift are ranges (as a fraction of total width or height) within which to randomly translate pictures vertically or horizontally
## shear_range is for randomly applying shearing transformations
## horizontal_flip and vertical_flip is for randomly flipping half of the images horizontally and vertically resp
## fill_mode is the strategy used for filling in newly created pixels, which can appear after a rotation or a width/height shift

trainAug = ImageDataGenerator(
	preprocessing_function=preprocess_input,
	rotation_range=30,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	vertical_flip=True,
	fill_mode="nearest")

# %%
# Initialize the validation data augmentation object
valAug = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
# As per the preprocessing step
# defining the ImageNet mean subtraction in RGB order and setting the 
# mean subtraction values for each of the data augmentation objects

# mean = np.array([123.68, 116.779, 103.939], dtype="float32")
# trainAug.mean = mean
# valAug.mean = mean

# %%
# Initialize the training generator
trainGen = trainAug.flow_from_directory(
	config.TRAIN_PATH,
	class_mode="categorical",
	target_size=(48, 48),
	color_mode="rgb",
	shuffle=True,
	batch_size=config.BATCH_SIZE)
# Out:
# Found 255690 images belonging to 2 classes.

# %%
# Initialize the validation generator
valGen = valAug.flow_from_directory(
	config.VAL_PATH,
	class_mode="categorical",
	target_size=(48, 48),
	color_mode="rgb",
	shuffle=False,
	batch_size=config.BATCH_SIZE)
# Out:
# Found 42634 images belonging to 2 classes.

# %%
# Initialize the testing generator
testGen = valAug.flow_from_directory(
	config.TEST_PATH,
	class_mode="categorical",
	target_size=(48, 48),
	color_mode="rgb",
	shuffle=False,
	batch_size=config.BATCH_SIZE)
# Out:
# Found 99785 images belonging to 2 classes.

# %%
# Loading the ResNet50, ensuring the head Full Connected layers are left off / removed
baseModel = ResNet50(weights="imagenet", include_top=False, input_tensor=Input(shape=(48, 48, 3)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
# Printing the baseModel layers after removing the head
baseModel.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 48, 48, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 54, 54, 3)    0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 24, 24, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 24, 24, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 24, 24, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 26, 26, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 12, 12, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 12, 12, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 12, 12, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 12, 12, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 12, 12, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 12, 12, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 12, 12, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 12, 12, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 12, 12, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 12, 12, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 12, 12, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 12, 12, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 12, 12, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 12, 12, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 12, 12, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 12, 12, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 12, 12, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 12, 12, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 12, 12, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 6, 6, 128)    32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 6, 6, 128)    147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 6, 6, 512)    131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 6, 6, 512)    66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 6, 6, 512)    0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 6, 6, 512)    0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 6, 6, 128)    65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 6, 6, 128)    147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 6, 6, 512)    66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 6, 6, 512)    0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 6, 6, 512)    0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 6, 6, 128)    65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 6, 6, 128)    147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 6, 6, 512)    66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 6, 6, 512)    0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 6, 6, 512)    0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 6, 6, 128)    65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 6, 6, 128)    147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 6, 6, 128)   512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 6, 6, 128)   0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 6, 6, 512)    66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 6, 6, 512)    0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 6, 6, 512)    0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 3, 3, 256)    131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 3, 3, 256)    590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 3, 3, 1024)   525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 3, 3, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 3, 3, 1024)  4096        ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 3, 3, 1024)  4096        ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 3, 3, 1024)   0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 3, 3, 1024)   0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 3, 3, 256)    262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 3, 3, 256)    590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 3, 3, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 3, 3, 1024)  4096        ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 3, 3, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 3, 3, 1024)   0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 3, 3, 256)    262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 3, 3, 256)    590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 3, 3, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 3, 3, 1024)  4096        ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 3, 3, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 3, 3, 1024)   0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 3, 3, 256)    262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 3, 3, 256)    590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 3, 3, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 3, 3, 1024)  4096        ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 3, 3, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 3, 3, 1024)   0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 3, 3, 256)    262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 3, 3, 256)    590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 3, 3, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 3, 3, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 3, 3, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 3, 3, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 3, 3, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 3, 3, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 3, 3, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 3, 3, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 3, 3, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 3, 3, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 3, 3, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 3, 3, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 2, 2, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 2, 2, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 2, 2, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 2, 2, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 2, 2, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 2, 2, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 2, 2, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 2, 2, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 2, 2, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 2, 2, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 2, 2, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 2, 2, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 2, 2, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 2, 2, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 2, 2, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 2, 2, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 2, 2, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 2, 2, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 2, 2, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 2, 2, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 2, 2, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 2, 2, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# Construct the head of the model that will be placed on top of the the base model
## Flattening is converting the data into a 1-dimensional array for inputting it to the next layer. 
## We flatten the output of the convolutional layers to create a single long feature vector. 
### Average pooling computes the average of the elements present in the region of feature map covered by the filter.
#### ReLU stands for Rectified Linear Unit. 
#### The main advantage of using the ReLU function over other activation functions is that it does not activate all the neurons at the same time.
## Dropout is a technique where randomly selected neurons are ignored during training.

headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7), padding="same")(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(256, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(len(config.CLASSES), activation="softmax")(headModel)

# %%
# Placing the head model on top of the base model
model = Model(inputs=baseModel.input, outputs=headModel)

# %%
# Loop over all the layers of the base model and freeze them so that they are 
# not updated during the training process
for layer in baseModel.layers:
    layer.trainable = False

# %%
# Printing all the layers of the model to check whether the baseModel layers are changed to not trainable
for layer in model.layers:
    print("{}: {}".format(layer, layer.trainable))
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f6f09dddca0>: False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x7f6f07734220>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef61c4070>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef5085520>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef5085d00>: False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x7f6ef504de20>: False
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7f6ef490e040>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef4914820>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef504dca0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef50852e0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef490d340>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef491dc40>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef4925fd0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef490ed60>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef4926040>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef4914f40>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef4926b20>: False
# <keras.layers.merging.add.Add object at 0x7f6ef4925550>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef4935eb0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48bcc10>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48c3d90>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48c3d60>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48c87c0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48d04c0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48c8700>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48d5c40>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48df820>: False
# <keras.layers.merging.add.Add object at 0x7f6ef48df490>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48d54f0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48ea4f0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48eacd0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48ea2b0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48f6760>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48f74c0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48f7b50>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef4880be0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef4884d60>: False
# <keras.layers.merging.add.Add object at 0x7f6ef4880670>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef488b160>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef488b850>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef488fee0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef488ba60>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48aa550>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48adb50>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48aadc0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef488f910>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48a2f40>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48948b0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48f6190>: False
# <keras.layers.merging.add.Add object at 0x7f6ef48f67f0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48aa460>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48bc3d0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef492f340>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48bc370>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef491d2e0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48e3040>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48e3a30>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48bd8b0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef483c970>: False
# <keras.layers.merging.add.Add object at 0x7f6ef48bd2e0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef483fac0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef4843d30>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef4845580>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef4845340>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef484d4f0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef4850ac0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48509d0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef485a850>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef485f910>: False
# <keras.layers.merging.add.Add object at 0x7f6ef485a940>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef4862a00>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef4869cd0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef486d520>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef486d2e0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef4877490>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef487b820>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef487b3a0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed1082820>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed10888e0>: False
# <keras.layers.merging.add.Add object at 0x7f6ed10828e0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed108f9d0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed1096e50>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed10a56a0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed1096c10>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed10a1e50>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef4862580>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef486d340>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed1096670>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef487ba30>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed109ae20>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48bc580>: False
# <keras.layers.merging.add.Add object at 0x7f6ef488b5b0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48c3910>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed1096970>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed1096b80>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed109af40>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef4845af0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef483f370>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef4845f40>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed10ae550>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed103d760>: False
# <keras.layers.merging.add.Add object at 0x7f6ed10b4af0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed10b7760>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed10445e0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed10aea90>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed1049580>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed1044a30>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed10535e0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed1044fa0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed105afd0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed1062d00>: False
# <keras.layers.merging.add.Add object at 0x7f6ed105afa0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed1044a00>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed1044ee0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed1071af0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed106afd0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed1071160>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed1000670>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed1000cd0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed107b430>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed100d220>: False
# <keras.layers.merging.add.Add object at 0x7f6ed100dd60>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed1006be0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed1062af0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed1017f40>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed1017970>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed1006700>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed1062f10>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed1053ee0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed105a250>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48bd0a0>: False
# <keras.layers.merging.add.Add object at 0x7f6ed10b0550>: False
# <keras.layers.core.activation.Activation object at 0x7f6ef48e7e80>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48bc940>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef48e7580>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed10b7490>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed101fc10>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed10299d0>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed1029a60>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ef48622b0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ef4862310>: False
# <keras.layers.merging.add.Add object at 0x7f6ed1082040>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed102dfd0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6eb977eca0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed103b940>: False
# <keras.layers.core.activation.Activation object at 0x7f6eb978a4c0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed102d0a0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6eb978fb20>: False
# <keras.layers.core.activation.Activation object at 0x7f6eb97943d0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed1032310>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6ed103b820>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6eb977ee80>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6eb979b490>: False
# <keras.layers.merging.add.Add object at 0x7f6eb97a6a90>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed103be80>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6eb97a6d00>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed103bf40>: False
# <keras.layers.core.activation.Activation object at 0x7f6eb97b48e0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6eb97b46d0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6eb97bbe80>: False
# <keras.layers.core.activation.Activation object at 0x7f6eb97bb160>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6eb97bbca0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6eb974ae20>: False
# <keras.layers.merging.add.Add object at 0x7f6eb9751820>: False
# <keras.layers.core.activation.Activation object at 0x7f6eb9751100>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6eb974a160>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6eb97bb250>: False
# <keras.layers.core.activation.Activation object at 0x7f6eb97a6c10>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6eb9794e20>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6eb97bb4f0>: False
# <keras.layers.core.activation.Activation object at 0x7f6eb977ea60>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x7f6eb97511c0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f6ed1027430>: False
# <keras.layers.merging.add.Add object at 0x7f6ed10ae370>: False
# <keras.layers.core.activation.Activation object at 0x7f6ed1071280>: False
# <keras.layers.pooling.average_pooling2d.AveragePooling2D object at 0x7f6eb96c11c0>: True
# <keras.layers.reshaping.flatten.Flatten object at 0x7f6eb96c1220>: True
# <keras.layers.core.dense.Dense object at 0x7f6eb9739f40>: True
# <keras.layers.regularization.dropout.Dropout object at 0x7f6eb975f430>: True
# <keras.layers.core.dense.Dense object at 0x7f6ed1096a30>: True

# %%
import tensorflow as tf

# %%
# Compiling the model
## Decay updates the learning rate by a decreasing factor in each epoch
print("Compiling model")
opt = tf.keras.optimizers.legacy.Adam(lr=config.INIT_LR, decay=config.INIT_LR / config.EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
# Out:
# Compiling model
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Using ModelCheckpoint to store the best performing model based on val_loss
MCName = os.path.sep.join([config.outputPath, "weights-{epoch:03d}-{val_loss:.4f}.hdf5"])
checkpoint = ModelCheckpoint(MCName, monitor="val_loss", mode="min", save_best_only=True, verbose=1)
callbacks = [checkpoint]

# %%
# Fitting the model on training data
print("Model Fitting")
MF = model.fit(
    x=trainGen,
    steps_per_epoch=totalTrain // config.BATCH_SIZE,
    validation_data=valGen,
    validation_steps=totalVal // config.BATCH_SIZE,
    class_weight=classWeight,
    callbacks=callbacks,
    epochs=config.EPOCHS)
# Out:
# Model Fitting
# Epoch 1/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.6468 - accuracy: 0.8031
# Epoch 1: val_loss improved from inf to 0.43181, saving model to /content/output/weights-001-0.4318.hdf5
# 7990/7990 [==============================] - 375s 46ms/step - loss: 0.6468 - accuracy: 0.8031 - val_loss: 0.4318 - val_accuracy: 0.8060
# Epoch 2/20
# 7990/7990 [==============================] - ETA: 0s - loss: 0.5971 - accuracy: 0.8175
# Epoch 2: val_loss did not improve from 0.43181
# 7990/7990 [==============================] - 362s 45ms/step - loss: 0.5971 - accuracy: 0.8175 - val_loss: 0.4423 - val_accuracy: 0.8023
# Epoch 3/20
# 7990/7990 [==============================] - ETA: 0s - loss: 0.5874 - accuracy: 0.8205
# Epoch 3: val_loss did not improve from 0.43181
# 7990/7990 [==============================] - 361s 45ms/step - loss: 0.5874 - accuracy: 0.8205 - val_loss: 0.4546 - val_accuracy: 0.7963
# Epoch 4/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5798 - accuracy: 0.8228
# Epoch 4: val_loss did not improve from 0.43181
# 7990/7990 [==============================] - 360s 45ms/step - loss: 0.5798 - accuracy: 0.8228 - val_loss: 0.4352 - val_accuracy: 0.8068
# Epoch 5/20
# 7990/7990 [==============================] - ETA: 0s - loss: 0.5740 - accuracy: 0.8252
# Epoch 5: val_loss improved from 0.43181 to 0.42596, saving model to /content/output/weights-005-0.4260.hdf5
# 7990/7990 [==============================] - 359s 45ms/step - loss: 0.5740 - accuracy: 0.8252 - val_loss: 0.4260 - val_accuracy: 0.8095
# Epoch 6/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5697 - accuracy: 0.8272
# Epoch 6: val_loss did not improve from 0.42596
# 7990/7990 [==============================] - 355s 44ms/step - loss: 0.5697 - accuracy: 0.8272 - val_loss: 0.4368 - val_accuracy: 0.8052
# Epoch 7/20
# 7990/7990 [==============================] - ETA: 0s - loss: 0.5668 - accuracy: 0.8285
# Epoch 7: val_loss did not improve from 0.42596
# 7990/7990 [==============================] - 357s 45ms/step - loss: 0.5668 - accuracy: 0.8285 - val_loss: 0.4699 - val_accuracy: 0.7883
# Epoch 8/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5637 - accuracy: 0.8292
# Epoch 8: val_loss did not improve from 0.42596
# 7990/7990 [==============================] - 356s 45ms/step - loss: 0.5637 - accuracy: 0.8292 - val_loss: 0.4311 - val_accuracy: 0.8058
# Epoch 9/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5638 - accuracy: 0.8286
# Epoch 9: val_loss did not improve from 0.42596
# 7990/7990 [==============================] - 356s 45ms/step - loss: 0.5638 - accuracy: 0.8286 - val_loss: 0.4539 - val_accuracy: 0.7964
# Epoch 10/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5613 - accuracy: 0.8300
# Epoch 10: val_loss improved from 0.42596 to 0.42498, saving model to /content/output/weights-010-0.4250.hdf5
# 7990/7990 [==============================] - 356s 45ms/step - loss: 0.5614 - accuracy: 0.8300 - val_loss: 0.4250 - val_accuracy: 0.8095
# Epoch 11/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5568 - accuracy: 0.8306
# Epoch 11: val_loss did not improve from 0.42498
# 7990/7990 [==============================] - 355s 44ms/step - loss: 0.5568 - accuracy: 0.8306 - val_loss: 0.4359 - val_accuracy: 0.8047
# Epoch 12/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5583 - accuracy: 0.8305
# Epoch 12: val_loss did not improve from 0.42498
# 7990/7990 [==============================] - 354s 44ms/step - loss: 0.5582 - accuracy: 0.8305 - val_loss: 0.4358 - val_accuracy: 0.8081
# Epoch 13/20
# 7990/7990 [==============================] - ETA: 0s - loss: 0.5557 - accuracy: 0.8323
# Epoch 13: val_loss did not improve from 0.42498
# 7990/7990 [==============================] - 356s 45ms/step - loss: 0.5557 - accuracy: 0.8323 - val_loss: 0.4411 - val_accuracy: 0.8032
# Epoch 14/20
# 7990/7990 [==============================] - ETA: 0s - loss: 0.5550 - accuracy: 0.8319
# Epoch 14: val_loss did not improve from 0.42498
# 7990/7990 [==============================] - 355s 44ms/step - loss: 0.5550 - accuracy: 0.8319 - val_loss: 0.4344 - val_accuracy: 0.8074
# Epoch 15/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5545 - accuracy: 0.8323
# Epoch 15: val_loss improved from 0.42498 to 0.42449, saving model to /content/output/weights-015-0.4245.hdf5
# 7990/7990 [==============================] - 358s 45ms/step - loss: 0.5545 - accuracy: 0.8323 - val_loss: 0.4245 - val_accuracy: 0.8123
# Epoch 16/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5519 - accuracy: 0.8321
# Epoch 16: val_loss improved from 0.42449 to 0.42427, saving model to /content/output/weights-016-0.4243.hdf5
# 7990/7990 [==============================] - 358s 45ms/step - loss: 0.5518 - accuracy: 0.8321 - val_loss: 0.4243 - val_accuracy: 0.8113
# Epoch 17/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5530 - accuracy: 0.8324
# Epoch 17: val_loss did not improve from 0.42427
# 7990/7990 [==============================] - 356s 45ms/step - loss: 0.5530 - accuracy: 0.8324 - val_loss: 0.4249 - val_accuracy: 0.8112
# Epoch 18/20
# 7990/7990 [==============================] - ETA: 0s - loss: 0.5514 - accuracy: 0.8337
# Epoch 18: val_loss did not improve from 0.42427
# 7990/7990 [==============================] - 360s 45ms/step - loss: 0.5514 - accuracy: 0.8337 - val_loss: 0.4269 - val_accuracy: 0.8094
# Epoch 19/20
# 7990/7990 [==============================] - ETA: 0s - loss: 0.5512 - accuracy: 0.8329
# Epoch 19: val_loss improved from 0.42427 to 0.41805, saving model to /content/output/weights-019-0.4181.hdf5
# 7990/7990 [==============================] - 359s 45ms/step - loss: 0.5512 - accuracy: 0.8329 - val_loss: 0.4181 - val_accuracy: 0.8159
# Epoch 20/20
# 7989/7990 [============================>.] - ETA: 0s - loss: 0.5501 - accuracy: 0.8346
# Epoch 20: val_loss improved from 0.41805 to 0.40766, saving model to /content/output/weights-020-0.4077.hdf5
# 7990/7990 [==============================] - 356s 45ms/step - loss: 0.5501 - accuracy: 0.8346 - val_loss: 0.4077 - val_accuracy: 0.8200

# %%
# Loading the best performing model
# Please specify the model name from the output folder which has the lowest val_loss
path1 = config.outputPath + '/weights-020-0.4077.hdf5'
fModel = load_model(path1)

# %%
# Predicting on the test data
print("Predicting on the test data")
predTest = fModel.predict(x=testGen, steps=(totalTest // config.BATCH_SIZE)+1)
predTest = np.argmax(predTest, axis=1)
# Out:
# Predicting on the test data
# 3119/3119 [==============================] - 51s 16ms/step

# %%
# Printing the Classification Report
print(classification_report(testGen.classes, predTest, target_names=testGen.class_indices.keys()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87     71572
#            1       0.64      0.86      0.74     28213
#
#     accuracy                           0.82     99785
#    macro avg       0.79      0.84      0.80     99785
# weighted avg       0.85      0.82      0.83     99785

# %%
# Computing the confusion matrix and and using the same to derive the 
# accuracy, sensitivity, and specificity
cm = confusion_matrix(testGen.classes, predTest)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])

# Printing the confusion matrix, accuracy, sensitivity, and specificity
print(cm)
print("acc: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# [[57969 13603]
#  [ 3890 24323]]
# acc: 0.8247
# sensitivity: 0.8099
# specificity: 0.8621

# %%
# Calculate roc auc
XGB_roc_value = roc_auc_score(testGen.classes, predTest)
print("XGboost roc_value: {0}" .format(XGB_roc_value))
# Out:
# XGboost roc_value: 0.8360299701766711

# %%
# Plotting the graph
training_plot(MF, config.EPOCHS, config.PLOT_PATH)

# %%
# Serialize/Writing the model to disk
print("Serializing network...")
fModel.save(config.MODEL_PATH, save_format="h5")
# Out:
# Serializing network...

# %%
cp '/content/output/weights-020-0.4077.hdf5' 'gdrive/MyDrive/Colab Notebooks/Breast_Cancer_Classification/output'
